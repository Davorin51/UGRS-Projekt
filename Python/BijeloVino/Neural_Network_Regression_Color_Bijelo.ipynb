# %%
import numpy
import tensorflow

print("Numpy version: ", numpy.__version__)
print("TensorFlow version: ", tensorflow.__version__)
# Out:
# 2023-06-12 19:14:48.737418: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-12 19:14:48.765928: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-12 19:14:48.767071: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-12 19:14:49.630499: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Numpy version:  1.23.5
# TensorFlow version:  2.12.0

# %%
import math
import numpy as np
import tensorflow as tf
#from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from numpy import asarray
from sklearn.datasets import make_multilabel_classification
from keras.models import Sequential
from keras.layers import Dense
from keras import layers
from pandas import read_csv
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
scaler_X = StandardScaler()
scaler_y = StandardScaler()
# get the dataset
def get_dataset():
    dataframe = pd.read_csv('TrainingRGB.csv')
    X = dataframe.iloc[:, :3].values.astype('float')
    y = dataframe.iloc[:, 3].values.astype('float')

    # Initialize the scaler
   # scaler_X = StandardScaler()
   # scaler_y = StandardScaler()

    # Standardize X and y
    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y.reshape(-1,1)) # reshape needed because fit_transform expects 2D array
    print(scaler_X.mean_)  # prints array of means for all features
    print(scaler_X.scale_)  # prints array of standard deviations for all features
    print(scaler_y.mean_)  # prints mean for the target y
    print(scaler_y.scale_)  # prints standard deviation for the target y
    print(X.shape, y.shape)
    return X, y.ravel()  # ravel() is used to convert y back to 1D array

# %%
def train_model():
    x_train, x_test, y_train, y_test = train_test_split(x_values, y_values, test_size=0.3)
    x_train, x_validate, y_train, y_validate = train_test_split(x_train, y_train, test_size=0.3)

    # create a NN with 2 layers of 16 neurons
    model = tf.keras.Sequential()
    model.add(layers.Dense(32, activation='relu', input_shape=(3,)))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(32, activation='relu'))
    model.add(layers.Dense(16, activation='relu'))
    model.add(layers.Dense(1))
    model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
    model.fit(x_train, y_train, epochs=250, validation_data=(x_validate, y_validate), verbose = 1)

    return model, x_train, y_train

# %%
x_values, y_values = get_dataset()
# Out:
# [1277.29967427 1598.31270358 1444.15960912]
# [ 914.6793255  1111.89861684  745.96838922]
# [4736.73289902]
# [3082.07271838]
# (307, 3) (307, 1)

# %%
tf_model, x_train, y_train = train_model()
# Out:
# Epoch 1/250
# 5/5 [==============================] - 1s 33ms/step - loss: 0.6627 - mae: 0.5956 - val_loss: 0.5276 - val_mae: 0.4412
# Epoch 2/250
# 5/5 [==============================] - 0s 7ms/step - loss: 0.3202 - mae: 0.2936 - val_loss: 0.2164 - val_mae: 0.2558
# Epoch 3/250
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1023 - mae: 0.1605 - val_loss: 0.0374 - val_mae: 0.1199
# Epoch 4/250
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0175 - mae: 0.0955 - val_loss: 0.0155 - val_mae: 0.1168
# Epoch 5/250
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0096 - mae: 0.0811 - val_loss: 0.0022 - val_mae: 0.0312
# Epoch 6/250
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0018 - mae: 0.0308 - val_loss: 0.0021 - val_mae: 0.0375
# Epoch 7/250
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0012 - mae: 0.0272 - val_loss: 0.0025 - val_mae: 0.0478
# Epoch 8/250
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0062 - mae: 0.0701 - val_loss: 0.0052 - val_mae: 0.0574
# Epoch 9/250
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0032 - mae: 0.0452 - val_loss: 0.0015 - val_mae: 0.0310
# Epoch 10/250
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0025 - mae: 0.0422 - val_loss: 0.0059 - val_mae: 0.0617
# Epoch 11/250
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0048 - mae: 0.0585 - val_loss: 0.0083 - val_mae: 0.0769
# Epoch 12/250
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0062 - mae: 0.0652 - val_loss: 0.0013 - val_mae: 0.0323
# Epoch 13/250
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0031 - mae: 0.0432 - val_loss: 0.0033 - val_mae: 0.0455
# Epoch 14/250
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0022 - mae: 0.0383 - val_loss: 0.0013 - val_mae: 0.0282
# Epoch 15/250
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0031 - mae: 0.0379 - val_loss: 0.0034 - val_mae: 0.0533
# Epoch 16/250
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0074 - mae: 0.0783 - val_loss: 0.0038 - val_mae: 0.0561
# Epoch 17/250
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0017 - mae: 0.0340 - val_loss: 0.0053 - val_mae: 0.0429
# Epoch 18/250
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0057 - mae: 0.0426 - val_loss: 5.2232e-04 - val_mae: 0.0145
# Epoch 19/250
# 5/5 [==============================] - 0s 7ms/step - loss: 5.0785e-04 - mae: 0.0169 - val_loss: 0.0041 - val_mae: 0.0552
# Epoch 20/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0054 - mae: 0.0601 - val_loss: 0.0013 - val_mae: 0.0313
# Epoch 21/250
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0010 - mae: 0.0256 - val_loss: 0.0041 - val_mae: 0.0523
# Epoch 22/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0030 - mae: 0.0446 - val_loss: 0.0013 - val_mae: 0.0343
# Epoch 23/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0044 - mae: 0.0561 - val_loss: 0.0014 - val_mae: 0.0310
# Epoch 24/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0044 - mae: 0.0471 - val_loss: 4.8286e-04 - val_mae: 0.0190
# Epoch 25/250
# 5/5 [==============================] - 0s 5ms/step - loss: 8.3753e-04 - mae: 0.0240 - val_loss: 0.0057 - val_mae: 0.0628
# Epoch 26/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0052 - mae: 0.0556 - val_loss: 0.0011 - val_mae: 0.0289
# Epoch 27/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0039 - mae: 0.0396 - val_loss: 7.1204e-04 - val_mae: 0.0231
# Epoch 28/250
# 5/5 [==============================] - 0s 5ms/step - loss: 5.3610e-04 - mae: 0.0191 - val_loss: 0.0043 - val_mae: 0.0523
# Epoch 29/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045 - mae: 0.0516 - val_loss: 0.0076 - val_mae: 0.0662
# Epoch 30/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0019 - mae: 0.0257 - val_loss: 2.0444e-04 - val_mae: 0.0107
# Epoch 31/250
# 5/5 [==============================] - 0s 6ms/step - loss: 9.6054e-04 - mae: 0.0189 - val_loss: 0.0021 - val_mae: 0.0411
# Epoch 32/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0051 - mae: 0.0581 - val_loss: 0.0059 - val_mae: 0.0633
# Epoch 33/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0063 - mae: 0.0567 - val_loss: 5.6102e-04 - val_mae: 0.0203
# Epoch 34/250
# 5/5 [==============================] - 0s 5ms/step - loss: 9.1055e-04 - mae: 0.0254 - val_loss: 0.0036 - val_mae: 0.0520
# Epoch 35/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0039 - mae: 0.0478 - val_loss: 2.6570e-04 - val_mae: 0.0139
# Epoch 36/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0016 - mae: 0.0212 - val_loss: 0.0027 - val_mae: 0.0362
# Epoch 37/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0047 - mae: 0.0470 - val_loss: 0.0045 - val_mae: 0.0546
# Epoch 38/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0043 - mae: 0.0504 - val_loss: 4.9300e-04 - val_mae: 0.0205
# Epoch 39/250
# 5/5 [==============================] - 0s 6ms/step - loss: 9.2430e-04 - mae: 0.0237 - val_loss: 0.0105 - val_mae: 0.0663
# Epoch 40/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0054 - mae: 0.0471 - val_loss: 0.0022 - val_mae: 0.0382
# Epoch 41/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0039 - mae: 0.0516 - val_loss: 0.0014 - val_mae: 0.0290
# Epoch 42/250
# 5/5 [==============================] - 0s 5ms/step - loss: 8.9955e-04 - mae: 0.0251 - val_loss: 0.0024 - val_mae: 0.0441
# Epoch 43/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0029 - mae: 0.0472 - val_loss: 0.0095 - val_mae: 0.0869
# Epoch 44/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0052 - mae: 0.0504 - val_loss: 6.5735e-04 - val_mae: 0.0228
# Epoch 45/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0013 - mae: 0.0288 - val_loss: 0.0039 - val_mae: 0.0556
# Epoch 46/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0041 - mae: 0.0530 - val_loss: 0.0016 - val_mae: 0.0340
# Epoch 47/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0019 - mae: 0.0304 - val_loss: 0.0139 - val_mae: 0.0839
# Epoch 48/250
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0062 - mae: 0.0607 - val_loss: 3.9394e-04 - val_mae: 0.0177
# Epoch 49/250
# 5/5 [==============================] - 0s 6ms/step - loss: 3.2016e-04 - mae: 0.0143 - val_loss: 0.0018 - val_mae: 0.0363
# Epoch 50/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0054 - mae: 0.0605 - val_loss: 0.0052 - val_mae: 0.0425
# Epoch 51/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0028 - mae: 0.0338 - val_loss: 0.0018 - val_mae: 0.0373
# Epoch 52/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0023 - mae: 0.0415 - val_loss: 0.0013 - val_mae: 0.0352
# Epoch 53/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0015 - mae: 0.0331 - val_loss: 0.0030 - val_mae: 0.0407
# Epoch 54/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0048 - mae: 0.0486 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 55/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0018 - mae: 0.0347 - val_loss: 0.0042 - val_mae: 0.0587
# Epoch 56/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0033 - mae: 0.0492 - val_loss: 0.0025 - val_mae: 0.0411
# Epoch 57/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0019 - mae: 0.0360 - val_loss: 0.0039 - val_mae: 0.0521
# Epoch 58/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0050 - mae: 0.0487 - val_loss: 0.0021 - val_mae: 0.0396
# Epoch 59/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0029 - mae: 0.0429 - val_loss: 0.0047 - val_mae: 0.0532
# Epoch 60/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0022 - mae: 0.0341 - val_loss: 9.8696e-04 - val_mae: 0.0198
# Epoch 61/250
# 5/5 [==============================] - 0s 5ms/step - loss: 4.2859e-04 - mae: 0.0117 - val_loss: 0.0060 - val_mae: 0.0477
# Epoch 62/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0046 - mae: 0.0421 - val_loss: 0.0041 - val_mae: 0.0578
# Epoch 63/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0045 - mae: 0.0570 - val_loss: 0.0014 - val_mae: 0.0317
# Epoch 64/250
# 5/5 [==============================] - 0s 5ms/step - loss: 9.1829e-04 - mae: 0.0196 - val_loss: 3.8489e-04 - val_mae: 0.0168
# Epoch 65/250
# 5/5 [==============================] - 0s 5ms/step - loss: 7.0967e-04 - mae: 0.0218 - val_loss: 0.0049 - val_mae: 0.0582
# Epoch 66/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0030 - mae: 0.0397 - val_loss: 2.7957e-04 - val_mae: 0.0145
# Epoch 67/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0054 - mae: 0.0350 - val_loss: 5.8431e-04 - val_mae: 0.0209
# Epoch 68/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0011 - mae: 0.0266 - val_loss: 0.0033 - val_mae: 0.0474
# Epoch 69/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0022 - mae: 0.0377 - val_loss: 0.0012 - val_mae: 0.0296
# Epoch 70/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0014 - mae: 0.0254 - val_loss: 0.0040 - val_mae: 0.0499
# Epoch 71/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0043 - mae: 0.0481 - val_loss: 0.0051 - val_mae: 0.0566
# Epoch 72/250
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0026 - mae: 0.0420 - val_loss: 0.0012 - val_mae: 0.0319
# Epoch 73/250
# 5/5 [==============================] - 0s 6ms/step - loss: 8.8478e-04 - mae: 0.0259 - val_loss: 0.0050 - val_mae: 0.0574
# Epoch 74/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0039 - mae: 0.0505 - val_loss: 0.0113 - val_mae: 0.0732
# Epoch 75/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0046 - mae: 0.0358 - val_loss: 2.5861e-04 - val_mae: 0.0137
# Epoch 76/250
# 5/5 [==============================] - 0s 5ms/step - loss: 9.4842e-04 - mae: 0.0227 - val_loss: 9.2551e-04 - val_mae: 0.0282
# Epoch 77/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0022 - mae: 0.0412 - val_loss: 0.0036 - val_mae: 0.0521
# Epoch 78/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0021 - mae: 0.0369 - val_loss: 0.0127 - val_mae: 0.0750
# Epoch 79/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0025 - mae: 0.0333 - val_loss: 0.0017 - val_mae: 0.0331
# Epoch 80/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0020 - mae: 0.0350 - val_loss: 0.0011 - val_mae: 0.0313
# Epoch 81/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0020 - mae: 0.0348 - val_loss: 0.0092 - val_mae: 0.0643
# Epoch 82/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0037 - mae: 0.0382 - val_loss: 3.2995e-04 - val_mae: 0.0161
# Epoch 83/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0020 - mae: 0.0348 - val_loss: 0.0036 - val_mae: 0.0519
# Epoch 84/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0030 - mae: 0.0409 - val_loss: 8.3571e-04 - val_mae: 0.0247
# Epoch 85/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0014 - mae: 0.0305 - val_loss: 0.0025 - val_mae: 0.0394
# Epoch 86/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0014 - mae: 0.0296 - val_loss: 6.5785e-04 - val_mae: 0.0228
# Epoch 87/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0019 - mae: 0.0355 - val_loss: 0.0178 - val_mae: 0.0907
# Epoch 88/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0058 - mae: 0.0481 - val_loss: 9.4345e-04 - val_mae: 0.0284
# Epoch 89/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0017 - mae: 0.0339 - val_loss: 0.0033 - val_mae: 0.0471
# Epoch 90/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0014 - mae: 0.0301 - val_loss: 8.8332e-04 - val_mae: 0.0261
# Epoch 91/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0026 - mae: 0.0407 - val_loss: 0.0052 - val_mae: 0.0472
# Epoch 92/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0012 - mae: 0.0198 - val_loss: 6.0119e-04 - val_mae: 0.0204
# Epoch 93/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0017 - mae: 0.0339 - val_loss: 0.0183 - val_mae: 0.1143
# Epoch 94/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0058 - mae: 0.0476 - val_loss: 3.9692e-04 - val_mae: 0.0158
# Epoch 95/250
# 5/5 [==============================] - 0s 7ms/step - loss: 7.4997e-04 - mae: 0.0219 - val_loss: 0.0037 - val_mae: 0.0511
# Epoch 96/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.
250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0022 - mae: 0.0371 - val_loss: 0.0057 - val_mae: 0.0655
# Epoch 232/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0025 - mae: 0.0355 - val_loss: 0.0013 - val_mae: 0.0224
# Epoch 233/250
# 5/5 [==============================] - 0s 6ms/step - loss: 1.9239e-04 - mae: 0.0077 - val_loss: 4.2185e-04 - val_mae: 0.0133
# Epoch 234/250
# 5/5 [==============================] - 0s 5ms/step - loss: 8.6699e-04 - mae: 0.0174 - val_loss: 0.0050 - val_mae: 0.0631
# Epoch 235/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0039 - mae: 0.0530 - val_loss: 9.0727e-04 - val_mae: 0.0195
# Epoch 236/250
# 5/5 [==============================] - 0s 5ms/step - loss: 5.7885e-04 - mae: 0.0149 - val_loss: 0.0083 - val_mae: 0.0517
# Epoch 237/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0018 - mae: 0.0203 - val_loss: 2.3862e-04 - val_mae: 0.0121
# Epoch 238/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0010 - mae: 0.0255 - val_loss: 0.0036 - val_mae: 0.0521
# Epoch 239/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0037 - mae: 0.0500 - val_loss: 0.0023 - val_mae: 0.0333
# Epoch 240/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0015 - mae: 0.0202 - val_loss: 2.2947e-04 - val_mae: 0.0113
# Epoch 241/250
# 5/5 [==============================] - 0s 6ms/step - loss: 3.1403e-04 - mae: 0.0137 - val_loss: 0.0016 - val_mae: 0.0338
# Epoch 242/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0021 - mae: 0.0389 - val_loss: 8.6338e-04 - val_mae: 0.0274
# Epoch 243/250
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0020 - mae: 0.0294 - val_loss: 6.8740e-04 - val_mae: 0.0235
# Epoch 244/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0011 - mae: 0.0292 - val_loss: 1.6399e-04 - val_mae: 0.0107
# Epoch 245/250
# 5/5 [==============================] - 0s 5ms/step - loss: 3.1977e-04 - mae: 0.0130 - val_loss: 6.5176e-04 - val_mae: 0.0237
# Epoch 246/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0028 - mae: 0.0415 - val_loss: 0.0121 - val_mae: 0.0890
# Epoch 247/250
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0042 - mae: 0.0356 - val_loss: 9.4109e-05 - val_mae: 0.0065
# Epoch 248/250
# 5/5 [==============================] - 0s 5ms/step - loss: 5.8970e-05 - mae: 0.0056 - val_loss: 1.2159e-04 - val_mae: 0.0085
# Epoch 249/250
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0011 - mae: 0.0225 - val_loss: 5.1964e-04 - val_mae: 0.0196
# Epoch 250/250
# 5/5 [==============================] - 0s 6ms/step - loss: 4.5418e-04 - mae: 0.0157 - val_loss: 0.0014 - val_mae: 0.0331

# %%
def standardize_data(new_data_point, scaler_X):
    # Reshape new_data_point to 2D because scaler expects 2D inputs
    new_data_point = np.array(new_data_point).reshape(1, -1)
    standardized_data_point = scaler_X.transform(new_data_point)
    return standardized_data_point[0]  # return as 1D array

new_data_point = [1081,1331,1461]
standardized_data_point = standardize_data(new_data_point, scaler_X)

# Reshape it to 2D because the model expects 2D inputs
standardized_data_point_2D = np.array(standardized_data_point).reshape(1, -1)


# Predict the target value
Y_pred2 = tf_model.predict(standardized_data_point_2D)

# Inverse-transform the prediction
Y_pred_orig = scaler_y.inverse_transform(Y_pred2)

print(Y_pred_orig)
# Out:
# 1/1 [==============================] - 0s 56ms/step
# [[4157.886]]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
test_dataframe = pd.read_csv('testRGB.csv')

X_test = test_dataframe.iloc[:, :3].values.astype('float')
Y_test = test_dataframe.iloc[:, 3].values.astype('float')

# Standardize X_test and Y_test
X_test = scaler_X.transform(X_test)
Y_test = scaler_y.transform(Y_test.reshape(-1,1))

# Remember to convert Y_test back to a 1D array if necessary
Y_test = Y_test.ravel()

# %%
newX = tf.convert_to_tensor([standardized_data_point], dtype=tf.float32)
yhat = tf_model.predict(newX)
print(yhat)

# Predictions for the test set
Y_pred = tf_model.predict(X_test)

# Inverse-transform predictions
Y_pred_orig = scaler_y.inverse_transform(Y_pred)

mae = mean_absolute_error(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)

print('Mean Absolute Error:', mae)
print('Mean Squared Error:', mse)

import matplotlib.pyplot as plt
import seaborn as sns

# Calculate predictions for the test set
Y_pred = tf_model.predict(X_test)

# Inverse-transform predictions
Y_pred_orig = scaler_y.inverse_transform(Y_pred)

# Create a scatter plot
# Create a scatter plot
c = "blue"
plt.figure(figsize=(8, 8))
plt.scatter(Y_test, Y_pred_orig, c=c, alpha=0.6)
plt.xlabel('Stvarne vrijednosti')
plt.ylabel('Predviđene vrijednosti')
plt.title('Stvarne vs Predviđene vrijednosti')
plt.grid(True)
plt.colorbar() # Show color scale
plt.show()


# Create a DataFrame for the metrics
metrics_df = pd.DataFrame(data=[[mae, mse]], 
                          columns=['Mean Absolute Error', 'Mean Squared Error'])

print(metrics_df)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# [[-0.18781076]]
# 5/5 [==============================] - 0s 1ms/step
# Mean Absolute Error: 0.03283216737828784
# Mean Squared Error: 0.0012805406432232459
# 5/5 [==============================] - 0s 971us/step
#    Mean Absolute Error  Mean Squared Error
# 0             0.032832            0.001281

# %%
from everywhereml.code_generators.tensorflow import tf_porter

# %%
porter = tf_porter(tf_model, x_train, y_train)
cpp_code = porter.to_arduino(instance_name='ColorRegressionNN_RGB', arena_size=4096)

print(cpp_code)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmpt386nejd/assets
# INFO:tensorflow:Assets written to: /tmp/tmpt386nejd/assets
# #ifndef UUID140007752994240
# #define UUID140007752994240
#
# #include <EloquentTinyML.h>
# #include <eloquent_tinyml/tensorflow.h>
#
# #ifdef __has_attribute
# #define HAVE_ATTRIBUTE(x) __has_attribute(x)
# #else
# #define HAVE_ATTRIBUTE(x) 0
# #endif
# #if HAVE_ATTRIBUTE(aligned) || (defined(__GNUC__) && !defined(__clang__))
# #define DATA_ALIGN_ATTRIBUTE __attribute__((aligned(4)))
# #else
# #define DATA_ALIGN_ATTRIBUTE
# #endif
#
# #ifndef ARENA_SIZE
# #define ARENA_SIZE 4096
# #endif
#
# /** model size = 89260 bytes **/
# const unsigned char modelData[] DATA_ALIGN_ATTRIBUTE = { , 0 ...
#
# /**
#  * Wrapper around the EloquentTinyML library
#  */
# template<uint32_t arenaSize>
# class TensorFlowPorter {
#     public:
#         Eloquent::TinyML::TensorFlow::AllOpsTensorFlow<3, 1, arenaSize> tf;
#
#         /**
#          * Init model
#          */
#         bool begin() {
#             return tf.begin(modelData);
#         }
#
#         /**
#          * Proxy
#          */
#         uint8_t predict(uint8_t *input, uint8_t *output = NULL) {
#             return tf.predict(input, output);
#         }
#
#         /**
#          * Proxy
#          */
#         int8_t predict(int8_t *input, int8_t *output = NULL) {
#             return tf.predict(input, output);
#         }
#
#         /**
#          * Proxy
#          */
#         float predict(float *input, float *output = NULL) {
#             return tf.predict(input, output);
#         }
#
#         /**
#          * Proxy
#          */
#         template<typename T>
#         uint8_t predictClass(T *input) {
#             return tf.predictClass(input);
#         }
#
#         /**
#          * Proxy
#          */
#         float getScoreAt(uint8_t index) {
#             return tf.getScoreAt(index);
#         }
#
#         /**
#          * Proxy
#          */
#         String getErrorMessage() {
#             return tf.getErrorMessage();
#         }
# };
#
#
#
# TensorFlowPorter<ARENA_SIZE> ColorRegressionNN_RGB;
#
#
# #endif
# 2023-05-31 20:30:54.178473: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# 2023-05-31 20:30:54.178502: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# 2023-05-31 20:30:54.178792: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: /tmp/tmpt386nejd
# 2023-05-31 20:30:54.179568: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
# 2023-05-31 20:30:54.179578: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: /tmp/tmpt386nejd
# 2023-05-31 20:30:54.183063: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:353] MLIR V1 optimization pass is not enabled
# 2023-05-31 20:30:54.184072: I tensorflow/cc/saved_model/loader.cc:231] Restoring SavedModel bundle.
# 2023-05-31 20:30:54.213472: I tensorflow/cc/saved_model/loader.cc:215] Running initialization op on SavedModel bundle at path: /tmp/tmpt386nejd
# 2023-05-31 20:30:54.223725: I tensorflow/cc/saved_model/loader.cc:314] SavedModel load for tags { serve }; Status: success: OK. Took 44931 microseconds.
# 2023-05-31 20:30:54.239015: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.

# %%
cpp_code = porter.to_arduino(instance_name='ColorRegressionNN_RGB', arena_size=4096)

# Specify the file path and name
file_path = 'ColorRegressionNN.txt'

# Open the file in write mode
with open(file_path, 'w') as file:
    # Write the C++ code to the file
    file.write(cpp_code)

print(f"The C++ code has been saved to {file_path}")
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmpuhiqvgud/assets
# INFO:tensorflow:Assets written to: /tmp/tmpuhiqvgud/assets
# The C++ code has been saved to ColorRegressionNN.txt
# 2023-05-31 20:31:22.185469: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# 2023-05-31 20:31:22.185507: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# 2023-05-31 20:31:22.185687: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: /tmp/tmpuhiqvgud
# 2023-05-31 20:31:22.186534: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
# 2023-05-31 20:31:22.186546: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: /tmp/tmpuhiqvgud
# 2023-05-31 20:31:22.189436: I tensorflow/cc/saved_model/loader.cc:231] Restoring SavedModel bundle.
# 2023-05-31 20:31:22.218688: I tensorflow/cc/saved_model/loader.cc:215] Running initialization op on SavedModel bundle at path: /tmp/tmpuhiqvgud
# 2023-05-31 20:31:22.226838: I tensorflow/cc/saved_model/loader.cc:314] SavedModel load for tags { serve }; Status: success: OK. Took 41152 microseconds.
