# %%
import math
import numpy as np
import tensorflow as tf
#from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from numpy import asarray
from sklearn.datasets import make_multilabel_classification
from keras.models import Sequential
from keras.layers import Dense
from keras import layers
from pandas import read_csv
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
# Out:
# 2023-06-12 19:19:16.540284: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-12 19:19:16.572939: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-12 19:19:16.573736: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-12 19:19:17.193316: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
scaler_X = StandardScaler()
scaler_y = StandardScaler()
# get the dataset
def get_dataset():
    dataframe = pd.read_csv('RGB_Roze_train.csv')
    X = dataframe.iloc[:, :3].values.astype('float')
    y = dataframe.iloc[:, 3].values.astype('float')

    # Initialize the scaler
   # scaler_X = StandardScaler()
   # scaler_y = StandardScaler()
    
    # Standardize X and y
    X = scaler_X.fit_transform(X)
    y = scaler_y.fit_transform(y.reshape(-1,1)) # reshape needed because fit_transform expects 2D array
    print(scaler_X.mean_)  # prints array of means for all features
    print(scaler_X.scale_)  # prints array of standard deviations for all features
    print(scaler_y.mean_)  # prints mean for the target y
    print(scaler_y.scale_)  # prints standard deviation for the target y


    print(X.shape, y.shape)
    return X, y.ravel()  # ravel() is used to convert y back to 1D array

# %%
def train_model():
    x_train, x_test, y_train, y_test = train_test_split(x_values, y_values, test_size=0.3)
    x_train, x_validate, y_train, y_validate = train_test_split(x_train, y_train, test_size=0.3)

    # create a NN with 2 layers of 16 neurons
    model = tf.keras.Sequential()
    model.add(layers.Dense(32, activation='relu', input_shape=(3,)))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(32, activation='relu'))
    model.add(layers.Dense(16, activation='relu'))
    model.add(layers.Dense(1))
    model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
    history = model.fit(x_train, y_train, epochs=250, validation_data=(x_validate, y_validate), verbose = 1)

    return model, x_train, y_train, history

# %%
x_values, y_values = get_dataset()
# Out:
# [3091.75369458 3551.8546798  2939.51970443]
# [656.00715891 777.14169421 585.69440775]
# [10400.55418719]
# [2239.78743401]
# (406, 3) (406, 1)

# %%
tf_model, x_train, y_train, history2 = train_model()

plt.figure(figsize=(12, 4))


plt.plot(history2.history['loss'], label='Train loss')
plt.plot(history2.history['val_loss'], label='Validation loss')
plt.title('Loss over epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()


plt.tight_layout()
plt.show()
# Out:
# Epoch 1/250
# 7/7 [==============================] - 1s 20ms/step - loss: 0.4435 - mae: 0.4418 - val_loss: 0.2021 - val_mae: 0.2760
# Epoch 2/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0865 - mae: 0.1482 - val_loss: 0.0126 - val_mae: 0.0465
# Epoch 3/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0194 - mae: 0.0515 - val_loss: 0.0020 - val_mae: 0.0302
# Epoch 4/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0059 - mae: 0.0310 - val_loss: 0.0118 - val_mae: 0.0488
# Epoch 5/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0148 - mae: 0.0656 - val_loss: 0.0079 - val_mae: 0.0365
# Epoch 6/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0082 - mae: 0.0417 - val_loss: 9.9989e-04 - val_mae: 0.0232
# Epoch 7/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0028 - mae: 0.0286 - val_loss: 5.3342e-04 - val_mae: 0.0175
# Epoch 8/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0017 - mae: 0.0260 - val_loss: 0.0110 - val_mae: 0.0480
# Epoch 9/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0096 - mae: 0.0438 - val_loss: 0.0158 - val_mae: 0.0807
# Epoch 10/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0057 - mae: 0.0329 - val_loss: 2.6852e-04 - val_mae: 0.0139
# Epoch 11/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0011 - mae: 0.0255 - val_loss: 0.0012 - val_mae: 0.0289
# Epoch 12/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0021 - mae: 0.0267 - val_loss: 0.0127 - val_mae: 0.0645
# Epoch 13/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0096 - mae: 0.0445 - val_loss: 0.0084 - val_mae: 0.0374
# Epoch 14/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0014 - mae: 0.0173 - val_loss: 0.0026 - val_mae: 0.0468
# Epoch 15/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0081 - mae: 0.0512 - val_loss: 2.5365e-04 - val_mae: 0.0122
# Epoch 16/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0101 - mae: 0.0362 - val_loss: 5.9755e-04 - val_mae: 0.0209
# Epoch 17/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0034 - mae: 0.0238 - val_loss: 8.7959e-04 - val_mae: 0.0215
# Epoch 18/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0012 - mae: 0.0192 - val_loss: 0.0061 - val_mae: 0.0363
# Epoch 19/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0039 - mae: 0.0413 - val_loss: 1.3456e-04 - val_mae: 0.0092
# Epoch 20/250
# 7/7 [==============================] - 0s 4ms/step - loss: 3.5224e-04 - mae: 0.0133 - val_loss: 0.0073 - val_mae: 0.0543
# Epoch 21/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0029 - mae: 0.0350 - val_loss: 0.0160 - val_mae: 0.0555
# Epoch 22/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0112 - mae: 0.0424 - val_loss: 0.0017 - val_mae: 0.0196
# Epoch 23/250
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0077 - mae: 0.0388 - val_loss: 0.0012 - val_mae: 0.0189
# Epoch 24/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0019 - mae: 0.0207 - val_loss: 0.0014 - val_mae: 0.0343
# Epoch 25/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0025 - mae: 0.0339 - val_loss: 8.0268e-04 - val_mae: 0.0150
# Epoch 26/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0070 - mae: 0.0336 - val_loss: 2.3122e-04 - val_mae: 0.0122
# Epoch 27/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0044 - mae: 0.0311 - val_loss: 5.4267e-04 - val_mae: 0.0162
# Epoch 28/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0013 - mae: 0.0267 - val_loss: 0.0602 - val_mae: 0.1087
# Epoch 29/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0067 - mae: 0.0375 - val_loss: 0.0105 - val_mae: 0.0469
# Epoch 30/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0047 - mae: 0.0363 - val_loss: 0.0017 - val_mae: 0.0379
# Epoch 31/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0051 - mae: 0.0279 - val_loss: 0.0958 - val_mae: 0.1255
# Epoch 32/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0128 - mae: 0.0316 - val_loss: 1.7021e-04 - val_mae: 0.0110
# Epoch 33/250
# 7/7 [==============================] - 0s 4ms/step - loss: 6.6185e-04 - mae: 0.0216 - val_loss: 0.0019 - val_mae: 0.0369
# Epoch 34/250
# 7/7 [==============================] - 0s 4ms/step - loss: 9.3074e-04 - mae: 0.0235 - val_loss: 9.4995e-05 - val_mae: 0.0083
# Epoch 35/250
# 7/7 [==============================] - 0s 4ms/step - loss: 5.2259e-04 - mae: 0.0130 - val_loss: 0.0036 - val_mae: 0.0353
# Epoch 36/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0100 - mae: 0.0482 - val_loss: 6.3845e-04 - val_mae: 0.0133
# Epoch 37/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0019 - mae: 0.0166 - val_loss: 0.0031 - val_mae: 0.0301
# Epoch 38/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0056 - mae: 0.0393 - val_loss: 0.0036 - val_mae: 0.0447
# Epoch 39/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0029 - mae: 0.0292 - val_loss: 0.0293 - val_mae: 0.1003
# Epoch 40/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0159 - mae: 0.0525 - val_loss: 0.0061 - val_mae: 0.0469
# Epoch 41/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.
250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0017 - mae: 0.0264 - val_loss: 0.0072 - val_mae: 0.0664
# Epoch 72/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0027 - mae: 0.0321 - val_loss: 3.3306e-04 - val_mae: 0.0137
# Epoch 73/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0018 - mae: 0.0191 - val_loss: 6.6985e-04 - val_mae: 0.0220
# Epoch 74/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0013 - mae: 0.0206 - val_loss: 0.0106 - val_mae: 0.0548
# Epoch 75/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0064 - mae: 0.0416 - val_loss: 0.0060 - val_mae: 0.0312
# Epoch 76/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0037 - mae: 0.0298 - val_loss: 0.0014 - val_mae: 0.0180
# Epoch 77/250
# 7/7 [==============================] - 0s 4ms/step - loss: 3.6374e-04 - mae: 0.0092 - val_loss: 2.3260e-04 - val_mae: 0.0087
# Epoch 78/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0079 - mae: 0.0390 - val_loss: 7.8852e-04 - val_mae: 0.0250
# Epoch 79/250
# 7/7 [==============================] - 0s 4ms/step - loss: 6.7642e-04 - mae: 0.0201 - val_loss: 1.3649e-04 - val_mae: 0.0100
# Epoch 80/250
# 7/7 [==============================] - 0s 4ms/step - loss: 9.8750e-04 - mae: 0.0200 - val_loss: 0.0952 - val_mae: 0.1385
# Epoch 81/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0123 - mae: 0.0371 - val_loss: 6.5893e-05 - val_mae: 0.0068
# Epoch 82/250
# 7/7 [==============================] - 0s 4ms/step - loss: 3.8965e-04 - mae: 0.0126 - val_loss: 0.0013 - val_mae: 0.0305
# Epoch 83/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0010 - mae: 0.0242 - val_loss: 1.1768e-04 - val_mae: 0.0072
# Epoch 84/250
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0010 - mae: 0.0177 - val_loss: 0.0163 - val_mae: 0.0602
# Epoch 85/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0062 - mae: 0.0422 - val_loss: 8.5245e-04 - val_mae: 0.0122
# Epoch 86/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0018 - mae: 0.0273 - val_loss: 0.0014 - val_mae: 0.0246
# Epoch 87/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0051 - mae: 0.0324 - val_loss: 0.0013 - val_mae: 0.0234
# Epoch 88/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0014 - mae: 0.0281 - val_loss: 0.0028 - val_mae: 0.0389
# Epoch 89/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0025 - mae: 0.0317 - val_loss: 0.0068 - val_mae: 0.0345
# Epoch 90/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0057 - mae: 0.0345 - val_loss: 0.0110 - val_mae: 0.0558
# Epoch 91/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0013 - mae: 0.0172 - val_loss: 0.0013 - val_mae: 0.0166
# Epoch 92/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0019 - mae: 0.0263 - val_loss: 0.0052 - val_mae: 0.0264
# Epoch 93/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0049 - mae: 0.0320 - val_loss: 0.0024 - val_mae: 0.0442
# Epoch 94/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0023 - mae: 0.0289 - val_loss: 0.0025 - val_mae: 0.0215
# Epoch 95/250
# 7/7 [==============================] - 0s 4ms/step - loss: 8.2041e-04 - mae: 0.0163 - val_loss: 0.0013 - val_mae: 0.0210
# Epoch 96/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0049 - mae: 0.0377 - val_loss: 0.0060 - val_mae: 0.0418
# Epoch 97/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0022 - mae: 0.0218 - val_loss: 0.0018 - val_mae: 0.0363
# Epoch 98/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0026 - mae: 0.0349 - val_loss: 0.0573 - val_mae: 0.0974
# Epoch 99/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0096 - mae: 0.0301 - val_loss: 6.6370e-04 - val_mae: 0.0224
# Epoch 100/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0012 - mae: 0.0270 - val_loss: 0.0020 - val_mae: 0.0203
# Epoch 101/250
# 7/7 [==============================] - 0s 4ms/step - loss: 5.9292e-04 - mae: 0.0118 - val_loss: 3.8943e-04 - val_mae: 0.0167
# Epoch 102/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.
250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0017 - mae: 0.0305 - val_loss: 3.9651e-04 - val_mae: 0.0102
# Epoch 236/250
# 7/7 [==============================] - 0s 4ms/step - loss: 7.5569e-04 - mae: 0.0156 - val_loss: 6.1244e-04 - val_mae: 0.0173
# Epoch 237/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0038 - mae: 0.0245 - val_loss: 0.0017 - val_mae: 0.0347
# Epoch 238/250
# 7/7 [==============================] - 0s 4ms/step - loss: 7.3008e-04 - mae: 0.0216 - val_loss: 7.1164e-04 - val_mae: 0.0230
# Epoch 239/250
# 7/7 [==============================] - 0s 4ms/step - loss: 4.9132e-04 - mae: 0.0190 - val_loss: 5.6047e-04 - val_mae: 0.0206
# Epoch 240/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0029 - mae: 0.0331 - val_loss: 8.0447e-04 - val_mae: 0.0155
# Epoch 241/250
# 7/7 [==============================] - 0s 4ms/step - loss: 9.4778e-04 - mae: 0.0152 - val_loss: 2.6617e-04 - val_mae: 0.0121
# Epoch 242/250
# 7/7 [==============================] - 0s 4ms/step - loss: 9.7184e-04 - mae: 0.0131 - val_loss: 0.0029 - val_mae: 0.0197
# Epoch 243/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0038 - mae: 0.0334 - val_loss: 4.5362e-04 - val_mae: 0.0162
# Epoch 244/250
# 7/7 [==============================] - 0s 4ms/step - loss: 6.5005e-04 - mae: 0.0128 - val_loss: 6.0892e-05 - val_mae: 0.0056
# Epoch 245/250
# 7/7 [==============================] - 0s 4ms/step - loss: 5.5963e-04 - mae: 0.0191 - val_loss: 7.4173e-05 - val_mae: 0.0071
# Epoch 246/250
# 7/7 [==============================] - 0s 4ms/step - loss: 3.5154e-04 - mae: 0.0111 - val_loss: 2.8809e-04 - val_mae: 0.0093
# Epoch 247/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0048 - mae: 0.0321 - val_loss: 0.0013 - val_mae: 0.0268
# Epoch 248/250
# 7/7 [==============================] - 0s 4ms/step - loss: 8.5421e-04 - mae: 0.0153 - val_loss: 1.5811e-04 - val_mae: 0.0090
# Epoch 249/250
# 7/7 [==============================] - 0s 4ms/step - loss: 7.7717e-04 - mae: 0.0216 - val_loss: 0.0061 - val_mae: 0.0369
# Epoch 250/250
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0053 - mae: 0.0330 - val_loss: 0.0015 - val_mae: 0.0187

# %%
tf_model.summary()
tf_model.save("moyModel")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                128
#
#  dense_1 (Dense)             (None, 64)                2112
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 16)                528
#
#  dense_6 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 21,441
# Trainable params: 21,441
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: moyModel/assets
# INFO:tensorflow:Assets written to: moyModel/assets

# %%
def calculate_mean_std(x_values):
    # Calculate mean and standard deviation for each feature
    mean = np.mean(x_values, axis=0)
    std_dev = np.std(x_values, axis=0)
    
    return mean, std_dev

# %%
mean, std_dev = calculate_mean_std(x_train)
for j in range(len(mean)):
    print(f"Feature {j} - Mean: {mean[j]}, Standard Deviation: {std_dev[j]}")
# Out:
# Feature 0 - Mean: 0.04673027711914628, Standard Deviation: 0.9032822917688704
# Feature 1 - Mean: 0.024830523818817753, Standard Deviation: 0.9602583555505135
# Feature 2 - Mean: 0.024533586568887676, Standard Deviation: 0.9520426951255995

# %%
def standardize_data(new_data_point, scaler_X):
    # Reshape new_data_point to 2D because scaler expects 2D inputs
    new_data_point = np.array(new_data_point).reshape(1, -1)
    standardized_data_point = scaler_X.transform(new_data_point)
    return standardized_data_point[0]  # return as 1D array

new_data_point = [3253,3737,3121]
standardized_data_point = standardize_data(new_data_point, scaler_X)

# Reshape it to 2D because the model expects 2D inputs
standardized_data_point_2D = np.array(standardized_data_point).reshape(1, -1)


# Predict the target value
Y_pred2 = tf_model.predict(standardized_data_point_2D)

# Inverse-transform the prediction
Y_pred_orig = scaler_y.inverse_transform(Y_pred2)

print(Y_pred_orig)
# Out:
# 1/1 [==============================] - 0s 76ms/step
# [[10973.777]]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
test_dataframe = pd.read_csv('RGB_Roze_test.csv')

X_test = test_dataframe.iloc[:, :3].values.astype('float')
Y_test = test_dataframe.iloc[:, 3].values.astype('float')

# Standardize X_test and Y_test
X_test = scaler_X.transform(X_test)
Y_test = scaler_y.transform(Y_test.reshape(-1,1))

# Remember to convert Y_test back to a 1D array if necessary
Y_test = Y_test.ravel()

# %%
newX = tf.convert_to_tensor([standardized_data_point], dtype=tf.float32)
yhat = tf_model.predict(newX)
print(yhat)

# Predictions for the test set
Y_pred = tf_model.predict(X_test)

# Inverse-transform predictions
Y_pred_orig = scaler_y.inverse_transform(Y_pred)

mae = mean_absolute_error(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)

print('Mean Absolute Error:', mae)
print('Mean Squared Error:', mse)

import matplotlib.pyplot as plt
import seaborn as sns
import time as time

start_time = time.time()
# Calculate predictions for the test set
Y_pred = tf_model.predict(X_test)

end_time = time.time()

full_time = end_time - start_time
print("Sekunde su ", full_time)
# Inverse-transform predictions
Y_pred_orig = scaler_y.inverse_transform(Y_pred)

c="blue"
# Create a scatter plot
plt.figure(figsize=(8, 8))
plt.scatter(Y_test, Y_pred_orig, c=c, alpha=0.6)
plt.xlabel('Stvarne vrijednosti')
plt.ylabel('Predviđene vrijednosti')
plt.title('Stvarne vs Predviđene vrijednosti')
plt.grid(True)
plt.colorbar() # Show color scale
plt.show()


# Create a DataFrame for the metrics
metrics_df = pd.DataFrame(data=[[mae, mse]], 
                          columns=['Mean Absolute Error', 'Mean Squared Error'])

print(metrics_df)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# [[0.25592768]]
# 5/5 [==============================] - 0s 900us/step
# Mean Absolute Error: 0.0462111776080816
# Mean Squared Error: 0.07233141036797779
# 5/5 [==============================] - 0s 1ms/step
# Sekunde su  0.049651384353637695
#    Mean Absolute Error  Mean Squared Error
# 0             0.046211            0.072331

# %%
from everywhereml.code_generators.tensorflow import tf_porter

# %%
porter = tf_porter(tf_model, x_train, y_train)
cpp_code = porter.to_arduino(instance_name='ColorRegressionNN_RGB_Roze', arena_size=4096)

print(cpp_code)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmp5p2rlniu/assets
# INFO:tensorflow:Assets written to: /tmp/tmp5p2rlniu/assets
# #ifndef UUID140010365625488
# #define UUID140010365625488
#
# #include <EloquentTinyML.h>
# #include <eloquent_tinyml/tensorflow.h>
#
# #ifdef __has_attribute
# #define HAVE_ATTRIBUTE(x) __has_attribute(x)
# #else
# #define HAVE_ATTRIBUTE(x) 0
# #endif
# #if HAVE_ATTRIBUTE(aligned) || (defined(__GNUC__) && !defined(__clang__))
# #define DATA_ALIGN_ATTRIBUTE __attribute__((aligned(4)))
# #else
# #define DATA_ALIGN_ATTRIBUTE
# #endif
#
# #ifndef ARENA_SIZE
# #define ARENA_SIZE 4096
# #endif
#
# /** model size = 89260 bytes **/
# const unsigned char modelData[] DATA_ALIGN_ATTRIBUTE = { , 0 ...
#
# /**
#  * Wrapper around the EloquentTinyML library
#  */
# template<uint32_t arenaSize>
# class TensorFlowPorter {
#     public:
#         Eloquent::TinyML::TensorFlow::AllOpsTensorFlow<3, 1, arenaSize> tf;
#
#         /**
#          * Init model
#          */
#         bool begin() {
#             return tf.begin(modelData);
#         }
#
#         /**
#          * Proxy
#          */
#         uint8_t predict(uint8_t *input, uint8_t *output = NULL) {
#             return tf.predict(input, output);
#         }
#
#         /**
#          * Proxy
#          */
#         int8_t predict(int8_t *input, int8_t *output = NULL) {
#             return tf.predict(input, output);
#         }
#
#         /**
#          * Proxy
#          */
#         float predict(float *input, float *output = NULL) {
#             return tf.predict(input, output);
#         }
#
#         /**
#          * Proxy
#          */
#         template<typename T>
#         uint8_t predictClass(T *input) {
#             return tf.predictClass(input);
#         }
#
#         /**
#          * Proxy
#          */
#         float getScoreAt(uint8_t index) {
#             return tf.getScoreAt(index);
#         }
#
#         /**
#          * Proxy
#          */
#         String getErrorMessage() {
#             return tf.getErrorMessage();
#         }
# };
#
#
#
# TensorFlowPorter<ARENA_SIZE> ColorRegressionNN_RGB_Roze;
#
#
# #endif
# 2023-06-12 19:19:27.848348: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# 2023-06-12 19:19:27.848402: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# 2023-06-12 19:19:27.848790: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: /tmp/tmp5p2rlniu
# 2023-06-12 19:19:27.849780: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
# 2023-06-12 19:19:27.849795: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: /tmp/tmp5p2rlniu
# 2023-06-12 19:19:27.853119: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:353] MLIR V1 optimization pass is not enabled
# 2023-06-12 19:19:27.854054: I tensorflow/cc/saved_model/loader.cc:231] Restoring SavedModel bundle.
# 2023-06-12 19:19:27.886434: I tensorflow/cc/saved_model/loader.cc:215] Running initialization op on SavedModel bundle at path: /tmp/tmp5p2rlniu
# 2023-06-12 19:19:27.895243: I tensorflow/cc/saved_model/loader.cc:314] SavedModel load for tags { serve }; Status: success: OK. Took 46455 microseconds.
# 2023-06-12 19:19:27.912263: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.

# %%
#cpp_code = porter.to_arduino(instance_name='ColorRegressionNN_RGB', arena_size=4096)

# Specify the file path and name
file_path = 'ColorRegressionNNRoze.txt'

# Open the file in write mode
with open(file_path, 'w') as file:
    # Write the C++ code to the file
    file.write(cpp_code)

print(f"The C++ code has been saved to {file_path}")
# Out:
# The C++ code has been saved to ColorRegressionNNRoze.txt
